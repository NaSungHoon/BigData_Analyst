# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"http://www.statiz.co.kr/main.php"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1000,800)
b = ['고영표','스탁','원태인','안우진','루친스키','양현종','장민재','배제성','스트레일리','문승원','요키시','데스파이네','뷰캐넌','구창모']
new=[]
for k in b:
    driver.find_element(By.XPATH,'//*[@id="search_text"]').send_keys(k)
    driver.find_element(By.XPATH,'//*[@id="search-btn"]').click()
    driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[1]/div/div[3]/div/div[2]/table/tbody/tr/td/a[4]').click()
    time.sleep(2)
    for i in range(1,len(driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody').find_elements(By.TAG_NAME,'tr'))+1):
        if driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']').get_attribute('class')=='colhead_stz0' :
            continue
        else :
            if driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[4]/span').text == '1':
                c_0 = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[1]/span').text
                c_1 = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[2]/span').text                 
                c_2 =driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[5]/span').text
                new.append([c_0,c_1,c_2,k])
            else :
                continue

# %%
re.findall(r'\D+,',driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[1]/div/div[1]/div').text)
# Out:
# ['Kiwoom\n안우진\n\n키움,']

# %%
new
 ['06-11', '@롯데', '9.0', '고영표'],
 ['06-17', '@두산', '8.0', '고영표'],
 ['06-24', 'LG', '4.2', '고영표'],
 ['07-01', '두산', '6.0', '고영표'],
 ['07-14', '삼성', '7.0', '고영표'],
 ['07-23', '@한화', '6.1', '고영표'],
 ['07-29', '@LG', '6.0', '고영표'],
 ['08-05', '한화', '6.0', '고영표'],
 ['08-12', '@SSG', '7.0', '고영표'],
 ['08-24', '@두산', '8.1', '고영표'],
 ['08-31', '두산', '6.0', '고영표'],
 ['09-06', '한화', '6.0', '고영표'],
 ['09-11', '@키움', '6.0', '고영표'],
 ['09-17', '롯데', '7.0', '고영표'],
 ['09-23', '@삼성', '7.0', '고영표'],
 ['10-05', '삼성', '5.0', '고영표'],
 ['10-11', '@LG', '3.0', '고영표'],
 ['10-19', '키움', '2.1', '고영표'],
# Out:
# [['04-06', 'SSG', '8.0', '고영표'],
#  ['04-12', '두산', '6.0', '고영표'],
#  ['04-19', '@LG', '7.0', '고영표'],
#  ['04-24', 'NC', '7.0', '고영표'],
#  ['04-30', '@키움', '6.0', '고영표'],
#  ['05-06', '@두산', '8.0', '고영표'],
#  ['05-13', '키움', '5.2', '고영표'],
#  ['05-19', 'LG', '5.1', '고영표'],
#  ['05-25', '@NC', '7.0', '고영표'],
#  ['05-31', '@SSG', '7.0', '고영표'],
#  ['06-05', 'KIA', '7.0', '고영표'],
#  ['06-11', '@롯데', '9.0', '고영표'],
#  ['06-17', '@두산', '8.0', '고영표'],
#  ['06-24', 'LG', '4.2', '고영표'],
#  ['07-01', '두산', '6.0', '고영표'],
#  ['07-14', '삼성', '7.0', '고영표'],
#  ['07-23', '@한화', '6.1', '고영표'],
#  ['07-29', '@LG', '6.0', '고영표'],
#  ['08-05', '한화', '6.0', '고영표'],
#  ['08-12', '@SSG', '7.0', '고영표'],
#  ['08-24', '@두산', '8.1', '고영표'],
#  ['08-31', '두산', '6.0', '고영표'],
#  ['09-06', '한화', '6.0', '고영표'],
#  ['09-11', '@키움', '6.0', '고영표'],
#  ['09-17', '롯데', '7.0', '고영표'],
#  ['09-23', '@삼성', '7.0', '고영표'],
#  ['10-05', '삼성', '5.0', '고영표'],
#  ['10-11', '@LG', '3.0', '고영표'],
#  ['10-19', '키움', '2.1', '고영표'],
#  ['04-02', '한화', '5.0', '스탁'],
#  ['04-08', '@롯데', '7.2', '스탁'],
#  ['04-14', '@KT', '6.0', '스탁'],
#  ['04-20', '@KIA', '6.2', '스탁'],
#  ['04-26', 'NC', '6.0', '스탁'],
#  ['05-01', '@SSG', '7.0', '스탁'],
#  ['05-07', 'KT', '5.0', '스탁'],
#  ['05-14', '@삼성', '7.0', '스탁'],
#  ['05-20', '롯데', '6.0', '스탁'],
#  ['05-26', '@한화', '6.0', '스탁'],
#  ['06-01', 'KIA', '5.0', '스탁'],
#  ['06-07', '한화', '6.0', '스탁'],
#  ['06-12', '@LG', '4.1', '스탁'],
#  ['06-18', 'KT', '7.0', '스탁'],
#  ['06-24', 'KIA', '6.0', '스탁'],
#  ['07-01', '@KT', '2.2', '스탁'],
#  ['07-07', '키움', '4.2', '스탁'],
#  ['07-13', '@NC', '5.2', '스탁'],
#  ['07-22', 'SSG', '7.0', '스탁'],
#  ['07-28', '롯데', '7.0', '스탁'],
#  ['08-06', '@KIA', '6.0', '스탁'],
#  ['08-12', 'NC', '7.0', '스탁'],
#  ['08-20', '@LG', '5.0', '스탁'],
#  ['08-26', '@한화', '7.0', '스탁'],
#  ['09-01', '롯데', '7.0', '스탁'],
#  ['09-07', '@NC', '4.1', '스탁'],
#  ['09-18', '@SSG', '1.0', '스탁'],
#  ['09-30', '@삼성', '4.0', '스탁'],
#  ['10-06', '삼성', '6.0', '스탁'],
#  ['04-05', '@두산', '5.1', '원태인'],
#  ['04-12', '한화', '7.0', '원태인'],
#  ['04-17', '@SSG', '5.0', '원태인'],
#  ['04-30', '@KIA', '5.2', '원태인'],
#  ['05-06', '@롯데', '8.0', '원태인'],
#  ['05-12', 'SSG', '7.0', '원태인'],
#  ['05-19', '@한화', '8.0', '원태인'],
#  ['05-25', 'KIA', '4.1', '원태인'],
#  ['05-31', '@키움', '5.0', '원태인'],
#  ['06-11', 'NC', '7.0', '원태인'],
#  ['06-17', '@KIA', '7.0', '원태인'],
#  ['06-23', '키움', '6.0', '원태인'],
#  ['06-29', 'KT', '6.0', '원태인'],
#  ['07-06', 'LG', '6.0', '원태인'],
#  ['07-12', '@KT', '5.0', '원태인'],
#  ['07-22', '@키움', '4.2', '원태인'],
#  ['07-28', '한화', '8.0', '원태인'],
#  ['08-04', '@두산', '7.0', '원태인'],
#  ['08-12', 'KIA', '5.0', '원태인'],
#  ['08-18', '@한화', '5.0', '원태인'],
#  ['08-25', '@롯데', '6.0', '원태인'],
#  ['09-01', '@KIA', '7.0', '원태인'],
#  ['09-08', '롯데', '7.0', '원태인'],
#  ['09-14', '@NC', '5.1', '원태인'],
#  ['09-20', '@키움', '7.0', '원태인'],
#  ['09-28', '@NC', '6.0', '원태인'],
#  ['10-04', '@KT', '5.0', '원태인'],
#  ['04-02', '롯데', '6.0', '안우진'],
#  ['04-08', '@삼성', '7.0', '안우진'],
#  ['04-14', 'NC', '7.0', '안우진'],
#  ['04-20', '@SSG', '6.0', '안우진'],
#  ['04-26', '@한화', '6.0', '안우진'],
#  ['05-01', 'KT', '5.0', '안우진'],
#  ['05-07', 'SSG', '6.0', '안우진'],
#  ['05-13', '@KT', '7.0', '안우진'],
#  ['05-19', '@NC', '6.0', '안우진'],
#  ['05-25', '@LG', '6.0', '안우진'],
#  ['05-31', '삼성', '8.0', '안우진'],
#  ['06-11', '@KIA', '6.0', '안우진'],
#  ['06-17', 'LG', '5.0', '안우진'],
#  ['06-23', '@삼성', '7.1', '안우진'],
#  ['06-29', 'KIA', '7.0', '안우진'],
#  ['07-05', '@두산', '7.2', '안우진'],
#  ['07-10', 'NC', '8.1', '안우진'],
#  ['07-22', '삼성', '6.0', '안우진'],
#  ['07-28', '@KT', '5.2', '안우진'],
#  ['08-03', 'SSG', '7.0', '안우진'],
#  ['08-10', '롯데', '7.0', '안우진'],
#  ['08-16', '@KT', '7.0', '안우진'],
#  ['08-21', 'SSG', '7.0', '안우진'],
#  ['08-27', '@LG', '8.0', '안우진'],
#  ['09-01', '한화', '6.0', '안우진'],
#  ['09-13', '@KIA', '7.0', '안우진'],
#  ['09-18', 'NC', '5.0', '안우진'],
#  ['09-24', '롯데', '6.0', '안우진'],
#  ['09-30', '@SSG', '6.0', '안우진'],
#  ['10-08', '@두산', '7.0', '안우진'],
#  ['10-16', 'KT', '6.0', '안우진'],
#  ['10-22', 'KT', '6.0', '안우진'],
#  ['10-27', 'LG', '6.0', '안우진'],
#  ['11-01', '@SSG', '2.2', '안우진'],
#  ['11-07', '@SSG', '6.0', '안우진'],
#  ['04-02', 'SSG', '7.0', '루친스키'],
#  ['04-08', '@LG', '7.0', '루친스키'],
#  ['04-14', '@키움', '6.0', '루친스키'],
#  ['04-20', '삼성', '7.0', '루친스키'],
#  ['04-26', '@두산', '5.0', '루친스키'],
#  ['05-01', '한화', '7.0', '루친스키'],
#  ['05-07', 'LG', '6.0', '루친스키'],
#  ['05-13', '@SSG', '7.2', '루친스키'],
#  ['05-19', '키움', '7.0', '루친스키'],
#  ['05-25', 'KT', '8.0', '루친스키'],
#  ['05-31', '@한화', '6.0', '루친스키'],
#  ['06-07', 'SSG', '7.0', '루친스키'],
#  ['06-12', '@삼성', '7.0', '루친스키'],
#  ['06-18', '한화', '7.0', '루친스키'],
#  ['06-24', '@SSG', '4.0', '루친스키'],
#  ['07-02', '삼성', '7.0', '루친스키'],
#  ['07-08', '@키움', '6.0', '루친스키'],
#  ['07-14', '두산', '4.2', '루친스키'],
#  ['07-24', 'LG', '7.0', '루친스키'],
#  ['07-30', '키움', '6.0', '루친스키'],
#  ['08-06', '@롯데', '6.0', '루친스키'],
#  ['08-12', '@두산', '6.0', '루친스키'],
#  ['08-18', '@KIA', '6.0', '루친스키'],
#  ['08-24', '롯데', '6.0', '루친스키'],
#  ['08-31', '@LG', '5.0', '루친스키'],
#  ['09-06', '두산', '6.0', '루친스키'],
#  ['09-11', '@롯데', '3.2', '루친스키'],
#  ['09-17', '@키움', '6.2', '루친스키'],
#  ['09-23', 'KIA', '6.0', '루친스키'],
#  ['09-29', '@삼성', '7.0', '루친스키'],
#  ['10-06', 'SSG', '6.0', '루친스키'],
#  ['04-02', 'LG', '6.0', '양현종'],
#  ['04-08', '@SSG', '6.0', '양현종'],
#  ['04-14', '롯데', '6.0', '양현종'],
#  ['04-20', '두산', '7.0', '양현종'],
#  ['04-26', '@KT', '6.2', '양현종'],
#  ['05-01', '삼성', '7.0', '양현종'],
#  ['05-07', '@한화', '6.0', '양현종'],
#  ['05-13', '@LG', '2.2', '양현종'],
#  ['05-19', '@롯데', '7.2', '양현종'],
#  ['05-25', '@삼성', '6.0', '양현종'],
#  ['05-31', '@두산', '5.0', '양현종'],
#  ['06-05', '@KT', '5.0', '양현종'],
#  ['06-11', '키움', '6.0', '양현종'],
#  ['06-17', '삼성', '6.0', '양현종'],
#  ['06-23', '롯데', '6.0', '양현종'],
#  ['06-29', '@키움', '7.0', '양현종'],
#  ['07-06', 'KT', '4.0', '양현종'],
#  ['07-12', '@LG', '6.0', '양현종'],
#  ['07-23', '@롯데', '6.1', '양현종'],
#  ['07-29', 'SSG', '6.2', '양현종'],
#  ['08-04', '@한화', '5.1', '양현종'],
#  ['08-12', '@삼성', '5.0', '양현종'],
#  ['08-18', 'NC', '7.0', '양현종'],
#  ['08-24', '@키움', '5.0', '양현종'],
#  ['08-31', '@한화', '6.0', '양현종'],
#  ['09-06', '@롯데', '6.0', '양현종'],
#  ['09-11', '@두산', '6.0', '양현종'],
#  ['09-16', '한화', '6.0', '양현종'],
#  ['09-22', '@NC', '5.0', '양현종'],
#  ['10-01', 'SSG', '5.0', '양현종'],
#  ['04-22', 'SSG', '4.0', '장민재'],
#  ['04-28', '키움', '5.0', '장민재'],
#  ['05-04', '@SSG', '4.0', '장민재'],
#  ['05-10', '@LG', '5.0', '장민재'],
#  ['05-15', '롯데', '5.0', '장민재'],
#  ['05-21', '@키움', '2.1', '장민재'],
#  ['05-27', '@KT', '5.0', '장민재'],
#  ['06-02', 'NC', '5.0', '장민재'],
#  ['06-10', '@SSG', '4.1', '장민재'],
#  ['06-16', '롯데', '5.0', '장민재'],
#  ['06-24', '삼성', '5.1', '장민재'],
#  ['07-01', '@키움', '5.0', '장민재'],
#  ['07-07', 'NC', '5.0', '장민재'],
#  ['07-12', '@롯데', '5.1', '장민재'],
#  ['07-26', '@삼성', '6.0', '장민재'],
#  ['08-02', 'KIA', '5.0', '장민재'],
#  ['08-07', '@KT', '4.0', '장민재'],
#  ['08-19', '삼성', '5.0', '장민재'],
#  ['08-25', '두산', '6.0', '장민재'],
#  ['09-01', '@키움', '2.0', '장민재'],
#  ['09-07', '@KT', '5.0', '장민재'],
#  ['09-13', 'KT', '5.1', '장민재'],
#  ['09-18', '@LG', '5.0', '장민재'],
#  ['09-24', '@LG', '5.2', '장민재'],
#  ['09-30', '롯데', '6.0', '장민재'],
#  ['04-03', '삼성', '7.0', '배제성'],
#  ['04-09', '@한화', '4.0', '배제성'],
#  ['04-15', '@롯데', '5.1', '배제성'],
#  ['04-22', 'NC', '5.1', '배제성'],
#  ['04-28', 'KIA', '6.0', '배제성'],
#  ['05-04', '롯데', '6.0', '배제성'],
#  ['05-10', '@KIA', '8.0', '배제성'],
#  ['05-15', '키움', '6.0', '배제성'],
#  ['05-21', '@삼성', '6.0', '배제성'],
#  ['05-27', '한화', '7.0', '배제성'],
#  ['06-03', 'KIA', '6.0', '배제성'],
#  ['06-10', '@롯데', '5.0', '배제성'],
#  ['06-16', 'SSG', '6.0', '배제성'],
#  ['06-22', 'NC', '5.0', '배제성'],
#  ['06-29', '@삼성', '4.0', '배제성'],
#  ['07-10', '롯데', '3.2', '배제성'],
#  ['08-14', '삼성', '2.1', '배제성'],
#  ['08-18', '@롯데', '5.1', '배제성'],
#  ['08-10', '@키움', '5.0', '스트레일리'],
#  ['08-18', 'KT', '6.0', '스트레일리'],
#  ['08-23', '@NC', '7.0', '스트레일리'],
#  ['08-28', '@SSG', '6.0', '스트레일리'],
#  ['09-02', '@두산', '6.0', '스트레일리'],
#  ['09-07', 'KIA', '5.0', '스트레일리'],
#  ['09-13', 'SSG', '5.0', '스트레일리'],
#  ['09-18', '@KT', '6.0', '스트레일리'],
#  ['09-23', '@LG', '5.0', '스트레일리'],
#  ['09-29', '@KIA', '6.1', '스트레일리'],
#  ['10-08', 'LG', '5.0', '스트레일리'],
#  ['04-03', '롯데', '6.0', '요키시'],
#  ['04-09', '@삼성', '6.2', '요키시'],
#  ['04-16', '@두산', '6.0', '요키시'],
#  ['04-22', 'KIA', '6.0', '요키시'],
#  ['04-27', '@한화', '7.0', '요키시'],
#  ['05-03', '@KIA', '7.0', '요키시'],
#  ['05-08', 'SSG', '5.1', '요키시'],
#  ['05-14', '@KT', '8.0', '요키시'],
#  ['05-20', '한화', '6.2', '요키시'],
#  ['05-26', '@LG', '5.1', '요키시'],
#  ['06-01', '삼성', '6.0', '요키시'],
#  ['06-08', 'KT', '6.0', '요키시'],
#  ['06-14', '두산', '6.0', '요키시'],
#  ['06-19', 'LG', '7.0', '요키시'],
#  ['06-30', 'KIA', '5.1', '요키시'],
#  ['07-06', '@두산', '6.0', '요키시'],
#  ['07-12', '@SSG', '5.0', '요키시'],
#  ['07-23', '삼성', '7.0', '요키시'],
#  ['07-29', '@NC', '6.0', '요키시'],
#  ['08-04', 'SSG', '7.0', '요키시'],
#  ['08-11', '롯데', '7.0', '요키시'],
#  ['08-17', '@KT', '6.1', '요키시'],
#  ['08-23', 'KIA', '4.0', '요키시'],
#  ['08-28', '@LG', '6.0', '요키시'],
#  ['09-02', '한화', '6.0', '요키시'],
#  ['09-08', 'LG', '7.0', '요키시'],
#  ['09-14', '@KIA', '7.2', '요키시'],
#  ['09-20', '삼성', '5.0', '요키시'],
#  ['09-27', '@NC', '5.0', '요키시'],
#  ['10-06', '@한화', '6.0', '요키시'],
#  ['10-17', 'KT', '6.0', '요키시'],
#  ['10-25', '@LG', '4.0', '요키시'],
#  ['11-04', 'SSG', '5.2', '요키시'],
#  ['04-05', 'SSG', '6.1', '데스파이네'],
#  ['04-10', '@한화', '5.1', '데스파이네'],
#  ['04-16', '@롯데', '6.0', '데스파이네'],
#  ['04-21', '@LG', '6.0', '데스파이네'],
#  ['04-26', 'KIA', '6.0', '데스파이네'],
#  ['05-01', '@키움', '5.0', '데스파이네'],
#  ['05-07', '@두산', '6.0', '데스파이네'],
#  ['05-12', '@KIA', '5.1', '데스파이네'],
#  ['05-17', 'LG', '7.0', '데스파이네'],
#  ['05-22', '@삼성', '7.0', '데스파이네'],
#  ['05-28', '한화', '4.0', '데스파이네'],
#  ['06-02', '@SSG', '5.0', '데스파이네'],
#  ['06-12', '@롯데', '5.1', '데스파이네'],
#  ['06-18', '@두산', '4.0', '데스파이네'],
#  ['06-25', 'LG', '6.0', '데스파이네'],
#  ['06-30', '@삼성', '5.2', '데스파이네'],
#  ['07-06', '@KIA', '5.2', '데스파이네'],
#  ['07-12', '삼성', '6.0', '데스파이네'],
#  ['07-26', '키움', '5.0', '데스파이네'],
#  ['08-03', '@NC', '6.2', '데스파이네'],
#  ['08-11', '@SSG', '6.0', '데스파이네'],
#  ['08-16', '키움', '6.0', '데스파이네'],
#  ['08-21', 'KIA', '5.0', '데스파이네'],
#  ['08-27', '@NC', '5.1', '데스파이네'],
#  ['09-03', '@KIA', '7.0', '데스파이네'],
#  ['09-09', 'NC', '5.0', '데스파이네'],
#  ['09-14', '@한화', '6.2', '데스파이네'],
#  ['09-20', '@SSG', '5.2', '데스파이네'],
#  ['09-29', '@LG', '2.0', '데스파이네'],
#  ['04-02', '@KT', '6.0', '뷰캐넌'],
#  ['04-08', '키움', '7.0', '뷰캐넌'],
#  ['04-14', '한화', '7.0', '뷰캐넌'],
#  ['04-20', '@NC', '6.0', '뷰캐넌'],
#  ['04-26', 'LG', '7.0', '뷰캐넌'],
#  ['05-01', '@KIA', '6.0', '뷰캐넌'],
#  ['05-07', '@롯데', '6.0', '뷰캐넌'],
#  ['05-14', '두산', '9.0', '뷰캐넌'],
#  ['05-20', 'KT', '7.0', '뷰캐넌'],
#  ['05-26', 'KIA', '5.0', '뷰캐넌'],
#  ['06-01', '@키움', '6.0', '뷰캐넌'],
#  ['06-07', '@롯데', '6.0', '뷰캐넌'],
#  ['06-12', 'NC', '6.0', '뷰캐넌'],
#  ['06-18', '@KIA', '6.0', '뷰캐넌'],
#  ['06-24', '@한화', '6.2', '뷰캐넌'],
#  ['06-30', 'KT', '4.0', '뷰캐넌'],
#  ['07-07', 'LG', '3.2', '뷰캐넌'],
#  ['07-14', '@KT', '7.0', '뷰캐넌'],
#  ['07-23', '@키움', '3.2', '뷰캐넌'],
#  ['08-28', '한화', '3.2', '뷰캐넌'],
#  ['09-06', '키움', '6.0', '뷰캐넌'],
#  ['09-11', 'LG', '7.2', '뷰캐넌'],
#  ['09-17', 'KIA', '7.0', '뷰캐넌'],
#  ['09-23', 'KT', '6.0', '뷰캐넌'],
#  ['09-29', 'NC', '8.2', '뷰캐넌'],
#  ['10-05', '@KT', '6.0', '뷰캐넌'],
#  ['05-28', '두산', '5.1', '구창모'],
#  ['06-03', '롯데', '7.0', '구창모'],
#  ['06-10', '@삼성', '5.0', '구창모'],
#  ['06-16', 'KIA', '5.1', '구창모'],
#  ['06-22', '@KT', '6.0', '구창모'],
#  ['06-28', '@LG', '5.2', '구창모'],
#  ['07-05', '@한화', '6.0', '구창모'],
#  ['07-10', '@키움', '5.1', '구창모'],
#  ['07-22', 'LG', '6.0', '구창모'],
#  ['07-28', '@KIA', '6.0', '구창모'],
#  ['08-03', 'KT', '5.0', '구창모'],
#  ['08-21', '@삼성', '5.2', '구창모'],
#  ['08-27', 'KT', '6.1', '구창모'],
#  ['09-03', '@한화', '5.0', '구창모'],
#  ['09-09', '@KT', '6.0', '구창모'],
#  ['09-15', 'SSG', '7.0', '구창모'],
#  ['09-22', 'KIA', '6.0', '구창모'],
#  ['09-28', '삼성', '7.0', '구창모'],
#  ['10-05', '롯데', '6.0', '구창모']]

# %%
import pandas as pd
new = pd.DataFrame(new)
new.to_csv('C:/Users/medici/Desktop/allstar.csv',encoding= 'cp949')

# %%
b = ['안우진','키움']

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1000,800)

driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').send_keys('2022-'+a[0][0])
time.sleep(1)     
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()
time.sleep(1)     
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
time.sleep(1)     
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()

if a[0][1][0] == '@':
    temp = b[1]
else :
    temp = a[0][1]
for i in range(1,len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul').find_elements(By.TAG_NAME,'li'))+1):    
    if driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul/li['+str(i)+']/div/span[1]').text.split(' ')[0] == temp:
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul/li['+str(i)+']').click()
    else:
        continue

driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[2]/button[4]').click()

# %%
if a[k][1][0] == '@':
    temp = b[1]
else :
    temp = a[k][1]
# Out:
# '키움'

# %%
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul/li[1]/div/span[1]').text.split(' ')[0]
# Out:
# '한화'

# %%
driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr[2]/td[4]/span').text
# Out:
# '1'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"http://www.statiz.co.kr/main.php"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1000,800)


name= '최원준'
driver.find_element(By.XPATH,'//*[@id="search_text"]').send_keys(name)
time.sleep(3)
driver.find_element(By.XPATH,'//*[@id="search-btn"]').click()
time.sleep(10)
driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div/div/div[2]/table/tbody/tr[2]/td[2]/a').click()
time.sleep(5)
driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[1]/div/div[3]/div/div[2]/table/tbody/tr/td/a[4]').click()
a= []
time.sleep(5)
for i in range(1,len(driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody').find_elements(By.TAG_NAME,'tr'))+1):
    if driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']').get_attribute('class')=='colhead_stz0' :
        continue
    else :
        if driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[4]/span').text == '1':
            c_0 = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[1]/span').text
            c_1 = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[2]/span').text                 
            c_2 =driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[5]/span').text
            a.append([c_0,c_1,c_2,name])
        else :
            continue

# %%
a
# Out:
# [['04-03', '한화', '6.0', '최원준'],
#  ['04-09', '@롯데', '6.0', '최원준'],
#  ['04-15', '키움', '6.0', '최원준'],
#  ['04-21', '@KIA', '6.1', '최원준'],
#  ['04-27', 'NC', '5.0', '최원준'],
#  ['05-03', '@LG', '6.1', '최원준'],
#  ['05-08', 'KT', '2.0', '최원준'],
#  ['05-15', '@삼성', '6.0', '최원준'],
#  ['05-21', '롯데', '6.0', '최원준'],
#  ['05-27', '@NC', '6.0', '최원준'],
#  ['06-02', 'KIA', '6.1', '최원준'],
#  ['06-08', '한화', '5.2', '최원준'],
#  ['06-19', 'KT', '5.0', '최원준'],
#  ['06-26', 'KIA', '5.2', '최원준'],
#  ['07-02', '@KT', '4.1', '최원준'],
#  ['07-08', 'LG', '6.1', '최원준'],
#  ['07-14', '@NC', '6.0', '최원준'],
#  ['07-26', '롯데', '6.1', '최원준'],
#  ['08-03', '삼성', '5.2', '최원준'],
#  ['08-10', 'NC', '3.2', '최원준'],
#  ['08-17', '@롯데', '5.0', '최원준'],
#  ['08-23', 'KT', '6.0', '최원준'],
#  ['08-28', '@KIA', '5.0', '최원준'],
#  ['09-03', '삼성', '6.0', '최원준'],
#  ['09-09', '한화', '5.0', '최원준'],
#  ['09-15', '@삼성', '2.1', '최원준'],
#  ['09-21', 'NC', '5.0', '최원준'],
#  ['09-27', '@KT', '7.0', '최원준'],
#  ['10-02', '@롯데', '6.0', '최원준'],
#  ['10-08', '키움', '7.0', '최원준']]

# %%
kimk = a

# %%
kimk = pd.DataFrame(kimk)

# %%
allstar_new = pd.concat([allstar_new,kimk],axis=0)

# %%
allstar_new
# Out:
#         0    1    2    3
# 0   04-09  KIA  6.0  김광현
# 1   04-15   삼성  7.0  김광현
# 2   04-21   키움  6.0  김광현
# 3   04-27  @롯데  6.0  김광현
# 4   05-03   한화  7.0  김광현
# ..    ...  ...  ...  ...
# 25  09-15  @삼성  2.1  최원준
# 26  09-21   NC  5.0  최원준
# 27  09-27  @KT  7.0  최원준
# 28  10-02  @롯데  6.0  최원준
# 29  10-08   키움  7.0  최원준
#
# [117 rows x 4 columns]

# %%
allstar = pd.concat([new,allstar_new],axis=0)
allstar
# Out:
#         0    1    2    3
# 0   04-06  SSG  8.0  고영표
# 1   04-12   두산  6.0  고영표
# 2   04-19  @LG  7.0  고영표
# 3   04-24   NC  7.0  고영표
# 4   04-30  @키움  6.0  고영표
# ..    ...  ...  ...  ...
# 25  09-15  @삼성  2.1  최원준
# 26  09-21   NC  5.0  최원준
# 27  09-27  @KT  7.0  최원준
# 28  10-02  @롯데  6.0  최원준
# 29  10-08   키움  7.0  최원준
#
# [459 rows x 4 columns]

# %%
import pandas as pd

allstar.to_csv('C:/Users/medici/Desktop/allstar_final.csv',encoding= 'cp949')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"http://www.statiz.co.kr/main.php"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1000,800)
b = ['임기영','고영표','원태인','이의리','이영하','양현종','임찬규','최원태']
a=[]
for k in b:
    driver.find_element(By.XPATH,'//*[@id="search_text"]').send_keys(k)
    driver.find_element(By.XPATH,'//*[@id="search-btn"]').click()
    driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[1]/div/div[3]/div/div[2]/table/tbody/tr/td/a[4]').click()
    time.sleep(2)
    for i in range(1,len(driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody').find_elements(By.TAG_NAME,'tr'))+1):
        if driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']').get_attribute('class')=='colhead_stz0' :
            continue
        else :
            if driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[4]/span').text == '1':
                c_0 = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[1]/span').text
                c_1 = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[2]/span').text                 
                c_2 =driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/div/section[2]/div/div[2]/div/div[3]/div/div/table/tbody/tr['+str(i)+']/td[5]/span').text
                a.append([c_0,c_1,c_2,k])
            else :
                continue
