# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

########
from collections import deque
#######



path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1000,800)

a= deque([])


for x in range(4,7):
    t1 = time.time()
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
    time.sleep(2)               
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
    time.sleep(2)                
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
    time.sleep(2)                  
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
    time.sleep(2)      
    for w in range(42):
        
        if driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].get_attribute('class')=='cell cur-month':
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].click()
            time.sleep(1)
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()
            time.sleep(1)
        else:
            continue
    
        for k in range(1,len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul').find_elements(By.TAG_NAME,'li'))+1):    
            driver.find_element(By.XPATH,'/html/body/div/div/div/div/section/aside/ul/li['+str(k)+']').click()
            time.sleep(3)
            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/div').find_elements(By.TAG_NAME,'image'))):
                c_0 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('x')
                c_1 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('y')
                if driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('xlink:href') =='/_nuxt/img/1c8f58b.png':
                    c_2 = 'ball'
                else:
                    c_2 = 'strike'  
                c_3 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/header').text.replace(' 공격','')
                c_4 = '공격'
                c_5 = re.findall(r'\d{4}.\d{2}.\d{2}',driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[1]').text.replace(' ',''))[0]
                if re.findall(r'\(\w{5}\)',driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[1]').text.replace(' ','')) == []:
                    c_6 = ''
                else:    
                    c_6 = re.sub(r'\(|\)','',re.findall(r'\(\w{5}\)',driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[1]').text.replace(' ',''))[0])
                a.append([c_0,c_1,c_2,c_3,c_4,c_5,c_6])

            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[2]/div/div').find_elements(By.TAG_NAME,'image'))):
                b_0 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('x')
                b_1 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('y')
                if driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('xlink:href') =='/_nuxt/img/1c8f58b.png':
                    b_2 = 'ball'
                else:
                    b_2 = 'strike'    
                b_4 = '수비'               
                a.append([b_0,b_1,b_2,c_3,b_4,c_5,c_6])
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
        time.sleep(1)
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
        time.sleep(1)                  
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
        time.sleep(1)                
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
        time.sleep(1)
    print(f"{x}달의 수집 시간:"+str(time.time()-t1))
# Out:
# 4달의 수집 시간:9297.890825271606
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28268\3357928402.py in <module>
#      68
#      69             for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[2]/div/div').find_elements(By.TAG_NAME,'image'))):
# ---> 70                 b_0 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('x')
#      71                 b_1 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('y')
#      72                 if driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('xlink:href') =='/_nuxt/img/1c8f58b.png':
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py in get_attribute(self, name)
#     175         if getAttribute_js is None:
#     176             _load_js()
# --> 177         attribute_value = self.parent.execute_script(f"return ({getAttribute_js}).apply(null, arguments);", self, name)
#     178         return attribute_value
#     179
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     498         command = Command.W3C_EXECUTE_SCRIPT
#     499
# --> 500         return self.execute(command, {"script": script, "args": converted_args})["value"]
#     501
#     502     def execute_async_script(self, script: str, *args):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=109.0.5414.120)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00BF6643]
# 	(No symbol) [0x00B8BE21]
# 	(No symbol) [0x00A8DA9D]
# 	(No symbol) [0x00A6EF6A]
# 	(No symbol) [0x00AE3AAB]
# 	(No symbol) [0x00AF61B6]
# 	(No symbol) [0x00ADFB76]
# 	(No symbol) [0x00AB49C1]
# 	(No symbol) [0x00AB5E5D]
# 	GetHandleVerifier [0x00E6A142+2497106]
# 	GetHandleVerifier [0x00E985D3+2686691]
# 	GetHandleVerifier [0x00E9BB9C+2700460]
# 	GetHandleVerifier [0x00CA3B10+635936]
# 	(No symbol) [0x00B94A1F]
# 	(No symbol) [0x00B9A418]
# 	(No symbol) [0x00B9A505]
# 	(No symbol) [0x00BA508B]
# 	BaseThreadInitThunk [0x76F000F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77E87BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77E87B8E+238]

# %%
import pandas as pd
a = pd.DataFrame(a)
a.to_csv('C:/Users/medici/Desktop/baseball.csv',encoding= 'cp949')

# %%
path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) # 정보가 웹브라우저에 담기도록 2초 딜레이 시켜줌
driver.set_window_size(1000,800)

a= []
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').send_keys('2022-04-05')
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()
if driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[0].get_attribute('class')=='cell cur-month':
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[0].click()
else:
    print('성공')
# Out:
# 성공

# %%
a
# Out:
# [['135.5295757142857',
#   '67.35809758241757',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['13.703628571428556',
#   '173.15530901098901',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['169.2332757142857',
#   '181.00632615384615',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['111.81679999999997',
#   '221.169069010989',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['193.4833285714286',
#   '-10.491090989011077',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['83.55919142857142',
#   '123.38008615384615',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['139.0793514285714', '-12', 'ball', '한화 이글스', '공격', '2022.04.02', '전일수심판'],
#  ['42.43929428571429',
#   '69.36449758241754',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['148.88993',
#   '96.92600615384613',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['94.84207857142856',
#   '75.30378901098898',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['8.32414285714286',
#   '77.52038329670327',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['118.34718142857142', '-12', 'ball', '한화 이글스', '공격', '2022.04.02', '전일수심판'],
#  ['54.43658142857143',
#   '228.36170901098902',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['100.18362857142856',
#   '277.17472843956045',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['39.881352857142836',
#   '158.97848615384615',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['99.14539857142854',
#   '122.36733186813188',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['158.85775714285714',
#   '1.7618461538460668',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['-12', '245.70621186813185', 'ball', '한화 이글스', '공격', '2022.04.02', '전일수심판'],
#  ['43.83217285714288',
#   '221.81528615384613',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['108.23432571428569',
#   '169.4369547252747',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['24.4209714285714',
#   '156.113069010989',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['204.75661428571428',
#   '185.80518329670326',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['161.86830857142857',
#   '157.52449758241758',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['64.13563571428573',
#   '236.0511718681319',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['152.58285428571426',
#   '83.45446329670327',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['54.80660571428571',
#   '85.85606329670327',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['58.50208142857143',
#   '169.914669010989',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['59.95263571428572',
#   '96.12692043956045',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['29.43788571428575', '292', 'ball', '한화 이글스', '공격', '2022.04.02', '전일수심판'],
#  ['55.40014857142856',
#   '86.26168615384613',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['10.63049999999999',
#   '91.73716043956041',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['140.88442',
#   '101.56938901098898',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['22.44764285714284',
#   '58.00792615384617',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['-3.161985714285736',
#   '159.35457758241756',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['113.57144428571426',
#   '18.402806153846115',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['47.37973285714283',
#   '167.54868043956043',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['178.17072857142858',
#   '128.76175472527473',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['97.75064',
#   '103.05204043956041',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['111.44294857142856',
#   '241.2295947252747',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['73.08463714285713',
#   '281.91452272527476',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['124.25917714285714',
#   '16.565777582417507',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['83.08852',
#   '105.21738901098902',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['152.74762285714286',
#   '51.03937758241755',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['157.4699142857143',
#   '148.8135947252747',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['82.07130571428571',
#   '262.5356518681319',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['48.40164714285711',
#   '132.3863032967033',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['32.79435714285713',
#   '70.50753758241758',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['176.76677142857145',
#   '49.59060043956037',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['168.63228',
#   '96.11736615384615',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['165.9514', '-12', 'ball', '한화 이글스', '공격', '2022.04.02', '전일수심판'],
#  ['27.884871428571437',
#   '162.08015472527472',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['87.03464',
#   '271.7755147252747',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['91.41470428571428',
#   '121.75933186813185',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['-12', '272.8056404395605', 'ball', '한화 이글스', '공격', '2022.04.02', '전일수심판'],
#  ['63.45252428571426',
#   '277.29980272527473',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['12.826071428571435',
#   '125.85204043956043',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['21.22631428571423',
#   '105.98694329670329',
#   'ball',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  ['152.14273285714285',
#   '184.38333186813188',
#   'strike',
#   '한화 이글스',
#   '공격',
#   '2022.04.02',
#   '전일수심판'],
#  
'292', 'ball', '삼성 라이온즈', '수비', '2022.04.02', '이영재심판'],
#  ['87.10097714285713',
#   '290.7658735824176',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['18.65004285714284',
#   '222.09236043956045',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['18.715171428571402',
#   '200.1635375824176',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['62.420404285714284',
#   '176.78072615384613',
#   'strike',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['36.4744571428571',
#   '195.71645186813188',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['-12', '218.74749186813187', 'ball', '삼성 라이온즈', '수비', '2022.04.02', '이영재심판'],
#  ['113.06196428571428',
#   '63.60673758241755',
#   'strike',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['162.5116042857143',
#   '270.2798347252747',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['113.47838428571428',
#   '155.91937758241758',
#   'strike',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['171.47188571428572',
#   '109.84166329670329',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['82.65215857142856', '-12', 'ball', '삼성 라이온즈', '수비', '2022.04.02', '이영재심판'],
#  ['43.52183857142854',
#   '278.52144843956046',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['-10.473842857142888',
#   '54.08024615384612',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['195.16055714285716',
#   '141.69912615384615',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['186.7509142857143',
#   '99.52564043956042',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['223', '31.594669010988973', 'ball', '삼성 라이온즈', '수비', '2022.04.02', '이영재심판'],
#  ['7.2780571428571506',
#   '192.44106901098903',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['155.16563857142856',
#   '169.21112615384615',
#   'strike',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['146.45049571428575',
#   '278.870701010989',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['50.35167714285712',
#   '185.819949010989',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['133.77191',
#   '203.98785758241758',
#   'strike',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['59.34210571428572', '292', 'ball', '삼성 라이온즈', '수비', '2022.04.02', '이영재심판'],
#  ['72.8224442857143',
#   '238.22520615384616',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['29.807171428571436',
#   '236.24052043956044',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['92.28501', '-12', 'ball', '삼성 라이온즈', '수비', '2022.04.02', '이영재심판'],
#  ['122.72717857142857',
#   '52.16765186813187',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판'],
#  ['182.90967142857144', '292', 'ball', '삼성 라이온즈', '수비', '2022.04.02', '이영재심판'],
#  ['196.79145714285713',
#   '179.016429010989',
#   'ball',
#   '삼성 라이온즈',
#   '수비',
#   '2022.04.02',
#   '이영재심판']]

# %%
if driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[0].get_attribute('class')=='cell cur-month':
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[0].click()
else:
    pass

# %%
len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[2]/div/div').find_elements(By.TAG_NAME,'image'))+1
# Out:
# 69

# %%
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/header').text.replace(' 공격','')
# Out:
# '키움 히어로즈'

# %%
import re
re.sub(r'\(|\)','',re.findall(r'\(\w{5}\)',driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[1]').text.replace(' ',''))[0])
# Out:
# '김병주심판'

# %%
import pandas as pd
a = pd.DataFrame(a)
a.to_csv('C:/Users/medici/Desktop/baseball_month10.csv',encoding='cp949')

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) # 정보가 웹브라우저에 담기도록 2초 딜레이 시켜줌
driver.set_window_size(1000,800)

a= []


for x in range(4,12):
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
    time.sleep(2)               
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
    time.sleep(2)                
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
    time.sleep(2)                  
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
    time.sleep(2)      
    for w in range(42):
        
        if driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].get_attribute('class')=='cell cur-month':
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].click()
            time.sleep(1)
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()
            time.sleep(1)
        else:
            continue
    
        for k in range(1,len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul').find_elements(By.TAG_NAME,'li'))+1):    
            driver.find_element(By.XPATH,'/html/body/div/div/div/div/section/aside/ul/li['+str(k)+']').click()
            time.sleep(3)
            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/div').find_elements(By.TAG_NAME,'image'))):
                c_5 = re.findall(r'\d{4}.\d{2}.\d{2}',driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[1]').text.replace(' ',''))[0]
                a.append([c_5])


        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
        time.sleep(1)
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
        time.sleep(1)                  
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
        time.sleep(1)                
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
        time.sleep(1)

# %%
a
# Out:
# [['135.5295757142857'],
#  ['13.703628571428556'],
#  ['169.2332757142857'],
#  ['111.81679999999997'],
#  ['193.4833285714286'],
#  ['83.55919142857142'],
#  ['139.0793514285714'],
#  ['42.43929428571429'],
#  ['148.88993'],
#  ['94.84207857142856'],
#  ['8.32414285714286'],
#  ['118.34718142857142'],
#  ['54.43658142857143'],
#  ['100.18362857142856'],
#  ['39.881352857142836'],
#  ['99.14539857142854'],
#  ['158.85775714285714'],
#  ['-12'],
#  ['43.83217285714288'],
#  ['108.23432571428569'],
#  ['24.4209714285714'],
#  ['204.75661428571428'],
#  ['161.86830857142857'],
#  ['64.13563571428573'],
#  ['152.58285428571426'],
#  ['54.80660571428571'],
#  ['58.50208142857143'],
#  ['59.95263571428572'],
#  ['29.43788571428575'],
#  ['55.40014857142856'],
#  ['10.63049999999999'],
#  ['140.88442'],
#  ['22.44764285714284'],
#  ['-3.161985714285736'],
#  ['113.57144428571426'],
#  ['47.37973285714283'],
#  ['178.17072857142858'],
#  ['97.75064'],
#  ['111.44294857142856'],
#  ['73.08463714285713'],
#  ['124.25917714285714'],
#  ['83.08852'],
#  ['152.74762285714286'],
#  ['157.4699142857143'],
#  ['82.07130571428571'],
#  ['48.40164714285711'],
#  ['32.79435714285713'],
#  ['176.76677142857145'],
#  ['168.63228'],
#  ['165.9514'],
#  ['27.884871428571437'],
#  ['87.03464'],
#  ['91.41470428571428'],
#  ['-12'],
#  ['63.45252428571426'],
#  ['12.826071428571435'],
#  ['21.22631428571423'],
#  ['152.14273285714285'],
#  ['137.52774714285715'],
#  ['128.62910285714287'],
#  ['130.0252042857143'],
#  ['128.6027157142857'],
#  ['141.18407857142859'],
#  ['138.2278457142857'],
#  ['160.61273714285716'],
#  ['107.06724857142858'],
#  ['189.54674285714287'],
#  ['79.01496285714285'],
#  ['104.18621571428572'],
#  ['184.93872857142856'],
#  ['168.5630557142857'],
#  ['175.48165714285713'],
#  ['55.77910285714283'],
#  ['44.14579714285712'],
#  ['88.48875285714283'],
#  ['203.40838571428569'],
#  ['95.97323428571428'],
#  ['85.52171'],
#  ['5.013328571428538'],
#  ['47.702555714285715'],
#  ['58.22182714285712'],
#  ['116.02128571428571'],
#  ['89.59721428571429'],
#  ['107.00238857142855'],
#  ['132.38735714285716'],
#  ['96.29807142857143'],
#  ['99.65816857142858'],
#  ['168.0704957142857'],
#  ['24.812414285714254'],
#  ['148.49687571428572'],
#  ['28.340771428571415'],
#  ['21.18602857142855'],
#  ['119.07124999999999'],
#  ['138.33044'],
#  ['191.1548142857143'],
#  ['-12'],
#  ['147.3721657142857'],
#  ['28.291757142857136'],
#  ['90.22560428571428'],
#  ['76.02213714285713'],
#  ['31.359514285714262'],
#  ['166.2824814285714'],
#  ['99.30600428571425'],
#  ['188.83838571428572'],
#  ['120.39933571428571'],
#  ['-5.832257142857176'],
#  ['101.49405571428572'],
#  ['50.8796214285714'],
#  ['144.99833'],
#  ['26.161985714285706'],
#  ['44.41658428571427'],
#  ['167.4421057142857'],
#  ['100.61851285714285'],
#  ['151.1819857142857'],
#  ['51.961091428571436'],
#  ['1.9422142857142575'],
#  ['94.10719999999998'],
#  ['208.1292'],
#  ['160.86244142857146'],
#  ['130.25496714285714'],
#  ['133.0616057142857'],
#  ['151.25987142857142'],
#  ['123.91016857142856'],
#  ['80.60530857142857'],
#  ['163.80202285714284'],
#  ['124.90959000000001'],
#  ['153.1831114285714'],
#  ['122.54656428571425'],
#  ['171.38325714285713'],
#  ['80.88119857142857'],
#  ['73.58431428571427'],
#  ['106.13644714285714'],
#  ['105.52779714285714'],
#  ['67.00841'],
#  ['70.86120142857142'],
#  ['162.5008614285714'],
#  ['74.36256714285712'],
#  ['-12'],
#  ['50.15528428571429'],
#  ['131.44876714285715'],
#  ['122.35104428571427'],
#  ['223'],
#  ['151.0009685714286'],
#  ['214.32581428571427'],
#  ['65.2786757142857'],
#  ['182.47794285714284'],
#  ['161.91141428571427'],
#  ['217.1834142857143'],
#  ['223'],
#  ['171.96874285714284'],
#  ['158.08017571428573'],
#  ['223'],
#  ['5.594114285714298'],
#  ['80.84091285714285'],
#  ['-12'],
#  ['199.4389'],
#  ['125.8135342857143'],
#  ['188.05214285714288'],
#  ['151.99233285714288'],
#  ['158.16940857142856'],
#  ['89.31165571428572'],
#  ['147.3937185714286'],
#  ['192.09347142857143'],
#  ['174.83305714285714'],
#  ['125.60606285714283'],
#  ['102.20516571428571'],
#  ['117.21186285714282'],
#  ['101.34808714285714'],
#  ['159.10135142857143'],
#  ['145.91274857142855'],
#  ['72.85037571428572'],
#  ['71.63999142857142'],
#  ['40.623147142857135'],
#  ['94.11686857142857'],
#  ['76.38148571428572'],
#  ['150.63900142857145'],
#  ['-12'],
#  ['100.18389714285713'],
#  ['54.93901142857143'],
#  ['90.21606999999997'],
#  ['129.67236857142856'],
#  ['71.38948142857141'],
#  ['73.76445857142856'],
#  ['71.17529571428568'],
#  ['147.63388857142857'],
#  ['101.28900142857144'],
#  ['-11.182200000000035'],
#  ['111.75328285714286'],
#  ['110.09592857142856'],
#  ['99.64480714285713'],
#  ['150.83123142857144'],
#  ['25.34284285714287'],
#  ['84.04228428571429'],
#  ['84.56176857142856'],
#  ['69.32040714285715'],
#  ['160.62173428571427'],
#  ['87.60716714285714'],
#  ['223'],
#  ['157.26418857142858'],
#  ['183.17757142857144'],
#  ['193.81635714285716'],
#  ['114.89100285714287'],
#  ['152.3062257142857'],
#  ['151.48688142857142'],
#  ['135.53226142857142'],
#  ['174.0474857142857'],
#  ['128.55484285714286'],
#  ['128.94548'],
#  ['19.4638142857143'],
#  ['161.38823714285712'],
#  ['146.93600571428573'],
#  ['8.73169999999994'],
#  ['215.26111428571426'],
#  ['-12'],
#  ['28.293771428571418'],
#  ['219.49917142857143'],
#  ['97.26794999999997'],
#  ['201.89095714285713'],
#  ['196.3322'],
#  ['75.55267428571426'],
#  ['200.6118857142857'],
#  ['210.8505'],
#  ['20.010357142857096'],
#  ['67.4237557142857'],
#  ['64.23816285714283'],
#  ['84.79945428571428'],
#  ['165.78589285714287'],
#  ['71.19000000000001'],
#  ['98.99553571428572'],
#  ['143.84991857142856'],
#  ['30.514185714285716'],
#  ['139.2978342857143'],
#  ['89.83067'],
#  ['102.7830642857143'],
#  ['45.828800000000015'],
#  ['126.14461571428575'],
#  ['144.47951714285713'],
#  ['76.98033285714287'],
#  ['116.57883999999999'],
#  ['83.73678428571426'],
#  ['13.250414285714253'],
#  ['35.19874285714281'],
#  ['175.79118571428575'],
#  ['70.09476571428571'],
#  ['70.20212714285712'],
#  ['-1.063100000000075'],
#  ['-12'],
#  ['161.44551'],
#  ['161.93088571428575'],
#  ['119.27791571428571'],
#  ['102.00447571428573'],
#  ['91.88886714285711'],
#  ['36.65037142857142'],
#  ['-12'],
#  ['123.50757999999999'],
#  ['129.80940714285714'],
#  ['148.98346'],
#  ['89.70994714285715'],
#  ['158.3998428571429'],
#  ['69.76697428571426'],
#  ['113.42849714285713'],
#  ['80.06796428571427'],
#  ['126.36121857142857'],
#  ['223'],
#  ['170.52691714285714'],
#  ['198.842'],
#  ['102.24833857142856'],
#  ['-12'],
#  ['85.58811428571428'],
#  ['-12'],
#  ['-12'],
#  ['131.65623857142856'],
#  ['68.30379714285716'],
#  ['183.5300714285714'],
#  ['139.39116285714283'],
#  ['58.674034285714285'],
#  ['-6.191471428571431'],
#  ['214.94151428571428'],
#  ['173.7789142857143'],
#  ['30.100585714285707'],
#  ['-12'],
#  ['223'],
#  ['71.95542857142856'],
#  ['55.07188714285712'],
#  ['88.40704'],
#  ['122.64734571428573'],
#  ['33.30195714285711'],
#  ['223'],
#  ['91.17312428571427'],
#  ['111.65183'],
#  ['-12'],
#  ['79.83598571428571'],
#  ['61.81101571428569'],
#  ['95.13273999999998'],
#  ['68.8299957142857'],
#  ['61.04061857142855'],
#  ['71.88177285714286'],
#  ['71.32173428571427'],
#  ['68.89599714285711'],
#  ['51.65740428571426'],
#  ['-2.1998285714285775'],
#  ['76.28681428571429'],
#  ['80.32216714285715'],
#  ['90.65431142857142'],
#  ['20.94431428571429'],
#  ['-9.615757142857142'],
#  ['-12'],
#  ['129.05901857142857'],
#  ['71.08243714285713'],
#  ['223'],
#  ['38.67694428571429'],
#  ['11.029328571428543'],
#  ['94.04610000000001'],
#  ['167.3206442857143'],
#  ['64.67875428571429'],
#  ['26.6930857142857'],
#  ['35.420985714285735'],
#  ['91.89873714285714'],
#  ['-12'],
#  ['98.12804999999997'],
#  ['22.010542857142823'],
#  ['93.8619942857143'],
#  ['45.21941142857141'],
#  ['126.80785285714285'],
#  ['-3.014271428571421'],
#  ['120.98267285714289'],
#  ['-12'],
#  ['29.29554285714284'],
#  ['142.96732571428572'],
#  ['16.78817142857142'],
#  ['100.45152857142857'],
#  ['76.49576285714285'],
#  ['101.87542714285712'],
#  ['167.7835942857143'],
#  ['27.507528571428544'],
#  ['55.417135714285735'],
#  ['166.21842714285717'],
#  ['188.82495714285716'],
#  ['103.04055714285715'],
#  ['18.75411428571425'],
#  ['88.67782714285715'],
#  ['-12'],
#  ['108.56352714285713'],
#  ['174.0119'],
#  ['51.508279999999964'],
#  ['150.34787'],
#  ['116.31187999999997'],
#  ['147.28481285714284'],
#  ['50.70766857142854'],
#  ['24.811742857142875'],
#  ['-11.847585714285731'],
#  ['40.61992428571427'],
#  ['31.374285714285712'],
#  ['147.72036857142857'],
#  ['106.33908428571429'],
#  ['83.46203571428573'],
#  ['154.15856285714284'],
#  ['95.12609285714285'],
#  ['159.27974999999998'],
#  ['146.94768857142856'],
#  ['83.84159428571428'],
#  ['77.26448142857141'],
#  ['-11.75358571428575'],
#  ['31.546842857142842'],
#  ['89.91493428571428'],
#  ['74.04706285714285'],
#  ['162.82744428571428'],
#  ['48.854995714285735'],
#  ['80.23125571428571'],
#  ['212.7499714285714'],
#  ['141.5200614285714'],
#  ['113.67477714285715'],
#  ['26.098199999999977'],
#  ['143.90470714285715'],
#  ['179.20875714285714'],
#  ['192.9784142857143'],
#  ['223'],
#  ['185.30264285714284'],
#  ['206.1693'],
#  ['161.7452357142857'],
#  ['80.21493999999998'],
#  ['201.98965714285714'],
#  ['139.4691828571428'],
#  ['158.6963457142857'],
#  ['138.30338142857144'],
#  ['171.02538571428568'],
#  ['135.00968857142857'],
#  ['133.65669285714282'],
#  ['176.24305714285714'],
#  ['137.03243428571432'],
#  ['112.60660142857144'],
#  ['157.47213'],
#  ['162.6058057142857'],
#  ['223'],
#  ['159.8642957142857'],
#  ['36.651714285714284'],
#  ['216.45357142857145'],
#  ['180.76848571428573'],
#  ['206.73195714285714'],
#  ['162.96938428571426'],
#  ['100.59890714285714'],
#  ['37.11674571428572'],
#  ['197.08419999999998'],
#  ['89.13077285714287'],
#  ['172.30781428571427'],
#  ['123.10619999999997'],
#  ['163.5476857142857'],
#  ['9.810014285714256'],
#  ['7.013514285714294'],
#  ['174.42885714285717'],
#  ['223'],
#  ['143.97238714285712'],
#  ['49.11920285714286'],
#  ['92.49221285714285'],
#  ['223'],
#  ['80.89422428571429'],
#  ['139.95476'],
#  ['35.33772857142856'],
#  ['183.35684285714282'],
#  ['142.70076857142857'],
#  ['133.45385428571427'],
#  ['80.80015714285712'],
#  ['63.83960285714285'],
#  ['82.83230285714288'],
#  ['86.22429285714287'],
#  ['-2.3562714285714197'],
#  ['191.8416857142857'],
#  ['92.7435957142857'],
#  ['115.70242428571427'],
#  ['118.74486857142858'],
#  ['3.301857142857166'],
#  ['46.06708999999997'],
#  ['16.63038571428571'],
#  ['122.89369285714287'],
#  ['173.43380000000002'],
#  ['40.082177142857105'],
#  ['88.33096714285712'],
#  ['67.17378285714287'],
#  ['112.86436285714288'],
#  ['97.2833257142857'],
#  ['117.99602428571427'],
#  ['138.44303857142856'],
#  ['24.151728571428585'],
#  ['122.83494285714286'],
#  ['35.467314285714274'],
#  ['67.89932857142858'],
#  ['95.83539'],
#  ['84.35987'],
#  ['79.1253457142857'],
#  ['78.0808714285714'],
#  ['103.10293285714283'],
#  ['36.27369999999997'],
#  ['116.35881285714282'],
#  ['103.63665142857143'],
#  ['78.47782'],
#  ['67.19150857142857'],
#  ['56.51183285714285'],
#  ['106.07702571428571'],
#  ['75.80083428571429'],
#  ['64.18787285714286'],
#  ['37.294069999999984'],
#  ['85.28160714285715'],
#  ['161.4674657142857'],
#  ['73.18494857142859'],
#  ['23.66695714285713'],
#  ['-12'],
#  ['93.76530857142855'],
#  ['125.11383857142857'],
#  ['78.29156571428571'],
#  ['157.8207357142857'],
#  ['223'],
#  ['133.8770557142857'],
#  ['67.14229285714285'],
#  ['38.236285714285714'],
#  ['29.98979999999999'],
#  ['112.09450285714287'],
#  ['60.45123857142853'],
#  ['136.65428571428572'],
#  ['95.63302142857142'],
#  ['81.08678999999998'],
#  ['138.58088285714285'],
#  ['166.1771342857143'],
#  ['182.43362857142856'],
#  ['55.19677285714285'],
#  ['51.273481428571415'],
#  ['97.14507857142854'],
#  ['83.76827428571428'],
#  ['70.52743428571428'],
#  ['177.36971428571428'],
#  ['58.58184714285713'],
#  ['51.579652857142854'],
#  ['138.4130257142857'],
#  ['87.18638285714285'],
#  ['60.170514285714276'],
#  ['165.05423714285712'],
#  ['220.1867142857143'],
#  ['149.55021285714287'],
#  ['156.55294428571432'],
#  ['223'],
#  ['203.21904285714285'],
#  ['148.61551714285713'],
#  ['157.82798714285715'],
#  ['94.32252714285715'],
#  ['41.48445571428571'],
#  ['152.11567428571425'],
#  ['68.64078714285716'],
#  ['173.77085714285715'],
#  ['138.04676142857144'],
#  ['146.66065285714285'],
#  ['95.2377514285714'],
#  ['90.05210714285715'],
#  ['153.34915571428573'],
#  ['152.3701457142857'],
#  ['32.910514285714285'],
#  ['89.83657857142857'],
#  ['175.48702857142857'],
#  ['162.03589714285712'],
#  ['81.88605857142853'],
#  ['-2.2542142857143617'],
#  ['110.60413285714286'],
#  ['203.18547142857142'],
#  ['-12'],
#  ['137.25924285714282'],
#  ['63.03764857142856'],
#  ['57.47378857142854'],
#  ['124.66599571428571'],
#  ['36.020571428571415'],
#  ['64.74972428571427'],
#  ['69.21955857142854'],
#  ['38.52311999999997'],
#  ['165.52564714285714'],
#  ['43.06385714285714'],
#  ['111.06580714285714'],
#  ['149.45433285714284'],
#  ['168.3086514285714'],
#  ['77.59113142857142'],
#  ['49.782708571428564'],
#  ['58.19624571428572'],
#  ['69.8390857142857'],
#  ['55.54329714285714'],
#  ['100.30314285714286'],
#  ['100.43011000000001'],
#  ['107.1419114285714'],
#  ['151.72926714285714'],
#  ['108.10191999999998'],
#  ['59.39622285714282'],
#  ['172.87987142857142'],
#  ['133.93620857142858'],
#  ['142.89541571428572'],
#  ['87.52263428571428'],
#  ['48.44575999999999'],
#  ['11.83504285714286'],
#  ['125.29707142857143'],
#  ['67.84165285714286'],
#  ['182.73644285714286'],
#  ['71.39767285714285'],
#  ['105.82315857142855'],
#  ['156.50715285714284'],
#  ['40.7685114285714'],
#  ['96.38938571428571'],
#  ['74.94798571428572'],
#  ['203.04984285714286'],
#  ['62.847902857142856'],
#  ['39.56860142857141'],
#  ['96.48741428571427'],
#  ['90.48524571428571'],
#  ['101.9020157142857'],
#  ['173.34114285714287'],
#  ['140.50627142857144'],
#  ['59.66714428571426'],
#  ['53.09365714285714'],
#  ['-8.510585714285693'],
#  ['118.84491142857141'],
#  ['223'],
#  ['109.43128142857142'],
#  ['60.87645428571426'],
#  ['187.8205'],
#  ['41.54528714285712'],
#  ['62.12141714285714'],
#  ['139.40673999999999'],
#  ['136.32421142857146'],
#  ['-12'],
#  ['77.03847857142857'],
#  ['76.51731571428571'],
#  ['65.26612'],
#  ['214.42720000000003'],
#  ['187.90174285714286'],
#  ['146.54691285714287'],
#  ['63.05094285714286'],
#  ['72.60557285714285'],
#  ['54.02331714285711'],
#  ['43.63020714285714'],
#  ['131.40384857142857'],
#  ['29.641328571428517'],
#  ['64.19237142857142'],
#  ['-12'],
#  ['-12'],
#  ['112.16963571428572'],
#  ['69.80705857142857'],
#  ['219.81205714285713'],
#  ['12.767657142857146'],
#  ['156.97930142857146'],
#  ['37.89540142857143'],
#  ['49.41879428571425'],
#  ['-12'],
#  ['109.24818285714282'],
#  ['19.083785714285668'],
#  ['42.98583714285712'],
#  ['148.73852285714287'],
#  ['-2.201171428571479'],
#  ['147.26675142857144'],
#  ['223'],
#  ['116.95719'],
#  ['114.36117857142855'],
#  ['195.0464142857143'],
#  ['-12'],
#  ['77.88259857142857'],
#  ['53.19551285714286'],
#  ['14.880642857142842'],
#  ['64.52821999999998'],
#  ['85.94377000000001'],
#  ['49.94727571428569'],
#  ['103.38311999999999'],
#  ['73.18400857142856'],
#  ['80.14987857142854'],
#  ['30.493371428571436'],
#  ['41.273224285714285'],
#  ['52.0157457142857'],
#  ['71.48428714285714'],
#  ['66.48274857142854'],
#  ['115.82522857142857'],
#  ['157.76158285714288'],
#  ['16.936557142857115'],
#  ['197.03249999999997'],
#  ['114.52017285714284'],
#  ['127.19513285714285'],
#  ['82.25594857142859'],
#  ['141.83798285714283'],
#  ['69.44099571428568'],
#  ['46.957337142857114'],
#  ['75.97560714285716'],
#  ['45.43164999999998'],
#  ['-12'],
#  ['32.57815714285713'],
#  ['150.14637428571427'],
#  ['62.926258571428576'],
#  ['155.8974957142857'],
#  ['223'],
#  ['3.7785714285713823'],
#  ['21.838657142857116'],
#  ['148.38823857142856'],
#  ['114.60081142857142'],
#  ['100.35799857142857'],
#  ['34.36550000000001'],
#  ['164.53441714285714'],
#  ['36.36837142857141'],
#  ['60.977034285714296'],
#  ['10.733900000000016'],
#  ['5.9768285714285625'],
#  ['37.41788142857141'],
#  ['86.00070714285714'],
#  ['96.59135142857141'],
#  ['101.97171'],
#  ['181.1391142857143'],
#  ['101.40206999999998'],
#  ['49.65184714285713'],
#  ['56.3566657142857'],
#  ['97.38712857142856'],
#  ['93.38501142857145'],
#  ['148.88549857142857'],
#  ['166.10791'],
#  ['150.01074571428572'],
#  ['77.52539857142854'],
#  ['20.430671428571443'],
#  ['136.43492999999998'],
#  ['85.14235285714285'],
#  ['132.17907999999997'],
#  ['65.52414999999998'],
#  ['102.22550999999997'],
#  ['20.826814285714264'],
#  ['127.00726714285716'],
#  ['52.634399999999985'],
#  ['75.92021428571427'],
#  ['35.00805714285715'],
#  ['33.41744285714285'],
#  ['177.94311428571427'],
#  ['121.59266571428572'],
#  ['188.04475714285712'],
#  ['111.98244142857143'],
#  ['74.06465428571428'],
#  ['87.10097714285713'],
#  ['18.65004285714284'],
#  ['18.715171428571402'],
#  ['62.420404285714284'],
#  ['36.4744571428571'],
#  ['-12'],
#  ['113.06196428571428'],
#  ['162.5116042857143'],
#  ['113.47838428571428'],
#  ['171.47188571428572'],
#  ['82.65215857142856'],
#  ['43.52183857142854'],
#  ['-10.473842857142888'],
#  ['195.16055714285716'],
#  ['186.7509142857143'],
#  ['223'],
#  ['7.2780571428571506'],
#  ['155.16563857142856'],
#  ['146.45049571428575'],
#  ['50.35167714285712'],
#  ['133.77191'],
#  ['59.34210571428572'],
#  ['72.8224442857143'],
#  ['29.807171428571436'],
#  ['92.28501'],
#  ['122.72717857142857'],
#  ['182.90967142857144'],
#  ['196.79145714285713']]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1000,800)

a= []


for x in range(9,10):
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
    time.sleep(2)               
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
    time.sleep(2)                
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
    time.sleep(2)                  
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
    time.sleep(2)      
    for w in range(27,42):
        
        if driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].get_attribute('class')=='cell cur-month':
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].click()
            time.sleep(1)
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()
            time.sleep(1)
        else:
            continue
    
        for k in range(1,len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul').find_elements(By.TAG_NAME,'li'))+1):    
            driver.find_element(By.XPATH,'/html/body/div/div/div/div/section/aside/ul/li['+str(k)+']').click()
            time.sleep(3)
            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/div').find_elements(By.TAG_NAME,'image'))):
                c_0 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('x')
                c_1 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('y')
                if driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('xlink:href') =='/_nuxt/img/1c8f58b.png':
                    c_2 = 'ball'
                else:
                    c_2 = 'strike'  
                c_3 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/header').text.replace(' 공격','')
                c_4 = '공격'
                c_5 = re.findall(r'\d{4}.\d{2}.\d{2}',driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[1]').text.replace(' ',''))[0]
                if re.findall(r'\(\w{5}\)',driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[1]').text.replace(' ','')) == []:
                    c_6 = ''
                else:    
                    c_6 = re.sub(r'\(|\)','',re.findall(r'\(\w{5}\)',driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[1]').text.replace(' ',''))[0])
                a.append([c_0,c_1,c_2,c_3,c_4,c_5,c_6])

            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[2]/div/div').find_elements(By.TAG_NAME,'image'))):
                b_0 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('x')
                b_1 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('y')
                if driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i].get_attribute('xlink:href') =='/_nuxt/img/1c8f58b.png':
                    b_2 = 'ball'
                else:
                    b_2 = 'strike'    
                b_4 = '수비'               
                a.append([b_0,b_1,b_2,c_3,b_4,c_5,c_6])
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
        time.sleep(1)
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
        time.sleep(1)                  
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
        time.sleep(1)                
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
        time.sleep(1)

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from time import sleep

from selenium.webdriver import ActionChains
from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver.common.actions.mouse_button import MouseButton

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) 


hoverable = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[0]
ActionChains(driver).move_to_element(hoverable).perform()
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[1]/span[1]').text
# Out:
# '폰트'

# %%
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[1]/span[1]').text
# Out:
# '폰트'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from time import sleep

from selenium.webdriver import ActionChains
from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver.common.actions.mouse_button import MouseButton

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1500,1200)
a= []
for x in range(4,12):
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
    time.sleep(2)               
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
    time.sleep(2)                
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
    time.sleep(2)                  
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
    time.sleep(2)      
    for w in range(42):
        
        if driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].get_attribute('class')=='cell cur-month':
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].click()
            time.sleep(1)
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()
            time.sleep(1)
        else:
            continue
    
        for k in range(1,len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul').find_elements(By.TAG_NAME,'li'))+1):    
            driver.find_element(By.XPATH,'/html/body/div/div/div/div/section/aside/ul/li['+str(k)+']').click()
            time.sleep(3)
            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/div').find_elements(By.TAG_NAME,'image'))):
                hoverable = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i]
                ActionChains(driver).move_to_element(hoverable).perform()
                driver.execute_script("arguments[0].move_to_element();", elem)
                c_7 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[1]/span[1]').text
                
                c_8 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[3]/span[1]').text
                
                a.append([c_7,c_8])
                        
            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[2]/div/div').find_elements(By.TAG_NAME,'image'))):    
                hoverable1 = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[2]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i]
                ActionChains(driver).move_to_element(hoverable1).perform()
                b_7 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[1]/span[1]').text
                b_8 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[3]/span[1]').text
                a.append([b_7,b_8])                      
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
        time.sleep(1)
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
        time.sleep(1)                  
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
        time.sleep(1)                
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8352\1998675242.py in <module>
#      50                 hoverable = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[i]
#      51                 ActionChains(driver).move_to_element(hoverable).perform()
# ---> 52                 c_7 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[1]/span[1]').text
#      53                 c_8 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[3]/span[1]').text
#      54                 a.append([c_7,c_8])
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     828             value = f'[name="{value}"]'
#     829
# --> 830         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     831
#     832     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__layout"]/div/div/section/section/section/div[2]/div[3]/span[1]/span[1]"}
#   (Session info: chrome=109.0.5414.120)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FB6643]
# 	(No symbol) [0x00F4BE21]
# 	(No symbol) [0x00E4DA9D]
# 	(No symbol) [0x00E81342]
# 	(No symbol) [0x00E8147B]
# 	(No symbol) [0x00EB8DC2]
# 	(No symbol) [0x00E9FDC4]
# 	(No symbol) [0x00EB6B09]
# 	(No symbol) [0x00E9FB76]
# 	(No symbol) [0x00E749C1]
# 	(No symbol) [0x00E75E5D]
# 	GetHandleVerifier [0x0122A142+2497106]
# 	GetHandleVerifier [0x012585D3+2686691]
# 	GetHandleVerifier [0x0125BB9C+2700460]
# 	GetHandleVerifier [0x01063B10+635936]
# 	(No symbol) [0x00F54A1F]
# 	(No symbol) [0x00F5A418]
# 	(No symbol) [0x00F5A505]
# 	(No symbol) [0x00F6508B]
# 	BaseThreadInitThunk [0x75DF00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F77BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F77B8E+238]

# %%
len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/div').find_elements(By.TAG_NAME,'image'))
# Out:
# 94

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from time import sleep

from selenium.webdriver import ActionChains
from selenium.webdriver.common.actions.action_builder import ActionBuilder
from selenium.webdriver.common.actions.mouse_button import MouseButton

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1500,1200)

hoverable = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[0]
driver.execute_script('arguments[0].move_to_element();', hoverable)
# Out:
# ---------------------------------------------------------------------------
# JavascriptException                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8352\846429054.py in <module>
#      26
#      27 hoverable = driver.find_element(By.XPATH,"//*[@id='__layout']/div/div/section/section/section/div/div[3]/div[1]/div/div/*[name()='svg']").find_elements(By.TAG_NAME,'image')[0]
# ---> 28 driver.execute_script('arguments[0].move_to_element();', hoverable)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute_script(self, script, *args)
#     498         command = Command.W3C_EXECUTE_SCRIPT
#     499
# --> 500         return self.execute(command, {"script": script, "args": converted_args})["value"]
#     501
#     502     def execute_async_script(self, script: str, *args):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     438         response = self.command_executor.execute(driver_command, params)
#     439         if response:
# --> 440             self.error_handler.check_response(response)
#     441             response["value"] = self._unwrap_value(response.get("value", None))
#     442             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     243                 alert_text = value["alert"].get("text")
#     244             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 245         raise exception_class(message, screen, stacktrace)
#
# JavascriptException: Message: javascript error: arguments[0].move_to_element is not a function
#   (Session info: chrome=109.0.5414.120)
# Stacktrace:
# Backtrace:
# 	(No symbol) [0x00FB6643]
# 	(No symbol) [0x00F4BE21]
# 	(No symbol) [0x00E4DA9D]
# 	(No symbol) [0x00E509E4]
# 	(No symbol) [0x00E508AD]
# 	(No symbol) [0x00E512E5]
# 	(No symbol) [0x00EB79F7]
# 	(No symbol) [0x00E9FD7C]
# 	(No symbol) [0x00EB6B09]
# 	(No symbol) [0x00E9FB76]
# 	(No symbol) [0x00E749C1]
# 	(No symbol) [0x00E75E5D]
# 	GetHandleVerifier [0x0122A142+2497106]
# 	GetHandleVerifier [0x012585D3+2686691]
# 	GetHandleVerifier [0x0125BB9C+2700460]
# 	GetHandleVerifier [0x01063B10+635936]
# 	(No symbol) [0x00F54A1F]
# 	(No symbol) [0x00F5A418]
# 	(No symbol) [0x00F5A505]
# 	(No symbol) [0x00F6508B]
# 	BaseThreadInitThunk [0x75DF00F9+25]
# 	RtlGetAppContainerNamedObjectPath [0x76F77BBE+286]
# 	RtlGetAppContainerNamedObjectPath [0x76F77B8E+238]

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time

from selenium.webdriver.support.ui import WebDriverWait

from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as ec
import re

path = r'C:\Users\medici\Downloads\driver\chromedriver.exe'
s = Service(path)
driver = webdriver.Chrome(service = s)

url = f"https://strikes.zone/game/221108KWHSSG"
driver.get(url)
driver.implicitly_wait(2) 
driver.set_window_size(1000,800)

a= []


for x in range(4,12):
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
    time.sleep(2)               
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
    time.sleep(2)                
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
    time.sleep(2)                  
    driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
    time.sleep(2)      
    for w in range(42):
        
        if driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].get_attribute('class')=='cell cur-month':
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/table/tbody').find_elements(By.TAG_NAME,'td')[w].click()
            time.sleep(1)
            driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[2]/button').click()
            time.sleep(1)
        else:
            continue
    
        for k in range(1,len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/ul').find_elements(By.TAG_NAME,'li'))+1):    
            driver.find_element(By.XPATH,'/html/body/div/div/div/div/section/aside/ul/li['+str(k)+']').click()
            time.sleep(3)
            c_0 = driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[2]/span[3]').text         
            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[1]/div/div').find_elements(By.TAG_NAME,'image'))):
           
                a.append(c_0)

            for i in range(len(driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/section/div/div[3]/div[2]/div/div').find_elements(By.TAG_NAME,'image'))):             
                a.append(c_0)
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[1]/input').click()
        time.sleep(1)
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[1]/a[6]').click()
        time.sleep(1)                  
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[1]/span[3]').click()
        time.sleep(1)                
        driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/aside/div/span[2]/div/div[2]/div[1]/div[2]/div[2]/span['+str(x)+']').click()
        time.sleep(1)

# %%
a
# Out:
# ['두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  '두산 베어스',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  'KIA 타이거즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  '키움 히어로즈',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'NC 다이노스',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz',
#  'kt wiz']

# %%
driver.find_element(By.XPATH,'//*[@id="__layout"]/div/div/section/section/header/div[1]/div[2]/span[3]').text
# Out:
# '두산 베어스'

# %%
len(a)
# Out:
# 116161

# %%
import pandas as pd
a= pd.DataFrame(a)
a.to_csv('C:/Users/medici/Desktop/away.csv',encoding='cp949')
